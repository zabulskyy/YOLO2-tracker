# %%
import torch
import numpy as np
import os, sys
sys.path.append("../")
import darknet
from detect import detect_with_model
from PIL import Image
from matplotlib import pyplot as plt

# %%
vot_path = "/data/vot2016/"
results_path = "heatmap_results/"

# %%
model = darknet.Darknet("../cfg/yolo.cfg")
model = model.cuda()
try:
    model.load_weights("../yolo.weights")
except:
    # !wget http://pjreddie.com/media/files/yolo.weights
    # !mv yolo.weights ..
    model.load_weights("../yolo.weights")

# %%
dataset_folders = [os.path.join(vot_path, x) for x in os.listdir(vot_path) if os.path.isdir(os.path.join(vot_path, x))]
dataset_folders.remove("/data/vot2016/soccer1")
dataset_folders.remove("/data/vot2016/road")
dataset_folders.remove("/data/vot2016/sphere")
dataset_folders.remove("/data/vot2016/glove")

# %%
for folder in dataset_folders:
    images = sorted([os.path.join(folder, x) for x in os.listdir(folder) if x.endswith(".jpg")])
    print(folder)
    res = []
            
    classname = folder.split('/')[-1]
    
    for n, image in enumerate(images):
        print(n+1, len(images), end=" ")
        _boxes = detect_with_model(model=model, image=image, verbose=0)
        for box in _boxes:
            x1, y1, x2, y2 = box[:4]
            dotx = (x1 + x2) / 2
            doty = (y1 + y2) / 2 
            res.append([n, float(box[0]), float(box[1])])
    print('\n'.join([','.join([str(y) for y in x]) for x in res]), 
          file=open(os.path.join(results_path, classname) + ".csv", "a+"))
# Out:
# /data/vot2016/nature
# 1 999
# ../utils.py:153: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   cls_confs = torch.nn.Softmax()(Variable(output[5:5 + num_classes].transpose(0, 1))).data
# 2 999 3 999 4 999 5 999 6 999 7 999 8 999 9 999 10 999 11 999 12 999 13 999 14 999 15 999 16 999 17 999 18 999 19 999 20 999 21 999 22 999 23 999 24 999 25 999 26 999 27 999 28 999 29 999 30 999 31 999 32 999
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1a924c46b8ac> in <module>
#       8     for n, image in enumerate(images):
#       9         print(n+1, len(images), end=" ")
# ---> 10         _boxes = detect_with_model(model=model, image=image, verbose=0)
#      11         for box in _boxes:
#      12             x1, y1, x2, y2 = box[:4]
#
# ~/YOLO2-tracker/detect.py in detect_with_model(model, image, verbose, use_cuda)
#      16     img = Image.open(image).convert('RGB')
#      17     sized = img.resize((model.width, model.height))
# ---> 18     boxes = do_detect(model, sized, 0.5, 0.4, use_cuda)
#      19
#      20     width = img.width
#
# ~/YOLO2-tracker/utils.py in do_detect(model, img, conf_thresh, nms_thresh, use_cuda)
#     362
#     363     # output, embed = model(img)
# --> 364     output, embed = model(img)
#     365     output = output.data
#     366     # print("====================")
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/YOLO2-tracker/darknet.py in forward(self, x)
#      92                 if (ind == 30):
#      93                     embed = x
# ---> 94                 x = self.models[ind](x)
#      95                 outputs[ind] = x
#      96             elif block['type'] == 'route':
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.5/site-packages/torch/nn/modules/activation.py in forward(self, input)
#     445
#     446     def forward(self, input):
# --> 447         return F.leaky_relu(input, self.negative_slope, self.inplace)
#     448
#     449     def extra_repr(self):
#
# ~/.local/lib/python3.5/site-packages/torch/nn/functional.py in leaky_relu(input, negative_slope, inplace)
#     752     """
#     753     if inplace:
# --> 754         return torch._C._nn.leaky_relu_(input, negative_slope)
#     755     return torch._C._nn.leaky_relu(input, negative_slope)
#     756
#
# KeyboardInterrupt:

# %%
plt.imshow(Image.open(images[0]))
for box in boxes:
    x1, y1, x2, y2 = box[:4]
    dotx = (x1 + x2) / 2
    doty = (y1 + y2) / 2 
    plt.plot([dotx], [doty], 'ro')

# %%
res = []
for i in boxes:
    for box in boxes[i]:
        res.append([i, float(box[0]), float(box[1])])

# %%
print('\n'.join([','.join([str(y) for y in x]) for x in res]), file=open("heatmap_results/birds2.csv", "a+"))
