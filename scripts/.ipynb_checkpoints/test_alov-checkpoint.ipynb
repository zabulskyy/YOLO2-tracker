jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000309.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000310.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000311.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000312.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000313.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000314.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000315.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000316.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000317.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000318.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000319.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000320.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000321.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000322.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000323.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000324.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000325.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000326.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000327.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000328.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000329.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000330.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000331.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000332.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000333.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000334.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000335.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000336.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000337.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000338.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000339.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000340.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000341.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000342.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000343.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000344.jpg',
#   '/data/alov/05-Shape/05-Shape_video00009/00000345.jpg'],
#  '/data/alov/groundtruth/05-Shape/05-Shape_video00009.ann')

# %%
cfgfile = "../cfg/yolo.cfg"
weightfile = "../yolo.weights"
namesfile = '../data/coco.names'
use_cuda=True
m = Darknet(cfgfile).cuda()
m.print_network()
m.load_weights(weightfile)
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32
#     1 max          2 x 2 / 2   416 x 416 x  32   ->   208 x 208 x  32
#     2 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64
#     3 max          2 x 2 / 2   208 x 208 x  64   ->   104 x 104 x  64
#     4 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#     5 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64
#     6 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128
#     7 max          2 x 2 / 2   104 x 104 x 128   ->    52 x  52 x 128
#     8 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
#     9 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128
#    10 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256
#    11 max          2 x 2 / 2    52 x  52 x 256   ->    26 x  26 x 256
#    12 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    13 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
#    14 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    15 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256
#    16 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512
#    17 max          2 x 2 / 2    26 x  26 x 512   ->    13 x  13 x 512
#    18 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    19 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
#    20 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    21 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512
#    22 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024
#    23 conv   1024  3 x 3 / 1    13 x  13 x1024   ->    13 x  13 x1024
#    24 conv   1024  3 x 3 / 1    13 x  13 x1024   ->    13 x  13 x1024
#    25 route  16
#    26 conv     64  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x  64
#    27 reorg              / 2    26 x  26 x  64   ->    13 x  13 x 256
#    28 route  27 24
#    29 conv   1024  3 x 3 / 1    13 x  13 x1280   ->    13 x  13 x1024
#    30 conv    425  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 425
#    31 detection

# %%
def plot_single(im, box=None, force_square=False, line="r-"):
    plt.imshow(im)

#     if pr_path is not None:
#         with open(pr_path, 'r') as f:
#             l = f.read().split("\n")[pr_idx]
#             if l == "":
#                 return
#             pr_bb = [float(x) for x in l.split(',')]

#         if (force_square):
#             X, Y = pr_bb[::2], pr_bb[1::2]
#             pr_bb = [min(X), min(Y), max(X),  max(Y)]
#             plt.plot([pr_bb[0], pr_bb[2], pr_bb[2], pr_bb[0], pr_bb[0], ],
#                      [pr_bb[1], pr_bb[1], pr_bb[3], pr_bb[3], pr_bb[1], ], 'r-', lw=2)
#         elif (len(pr_bb) == 8):
#             plt.plot(pr_bb[::2] + [pr_bb[0]],
#                      pr_bb[1::2] + [pr_bb[1]], 'r-', lw=2)
#         else:
#             plt.plot([pr_bb[0], pr_bb[2], pr_bb[2], pr_bb[0], pr_bb[0], ],
#                      [pr_bb[1], pr_bb[1], pr_bb[3], pr_bb[3], pr_bb[1], ], 'r-', lw=2)

    if box is not None:  
        width, height = im.width, im.height
        x1 = (box[0] - box[2] / 2.0) * width
        y1 = (box[1] - box[3] / 2.0) * height
        x2 = (box[0] + box[2] / 2.0) * width
        y2 = (box[1] + box[3] / 2.0) * height
        
        plt.plot([x1, x2, x2, x1, x1, ],
                     [y1, y1, y2, y2, y1, ], line, lw=2)
        
        return [x1, x2, y1, y2]

# %%
def iou(box_a, box_b):
    # IoU between two boxes
    box_a = box_a[1:5] if len(box_a) != 4 else box_a
    box_b = box_b[1:5] if len(box_b) != 4 else box_b

    x_a = np.max((box_a[0], box_b[0]))
    y_a = np.max((box_a[1], box_b[1]))
    x_b = np.min((box_a[2], box_b[2]))
    y_b = np.min((box_a[3], box_b[3]))

    inter_area = np.max((0., x_b - x_a + 1)) * np.max((0., y_b - y_a + 1))
    box_a_area = (box_a[2] - box_a[0] + 1) * (box_a[3] - box_a[1] + 1)
    box_b_area = (box_b[2] - box_b[0] + 1) * (box_b[3] - box_b[1] + 1)
    a = (box_a_area + box_b_area - inter_area)
    res = inter_area / a
    return res

# %%
def choose_best_by_emb(prev, candidates, thr=.3):
    best_dist = thr
    best_track_idx = 0
    
    prev_emb = np.array(prev[8:1032])
    
    for n, candidate in enumerate(candidates):
        cand_emb = np.array(candidate[8:1032])
        emb_dist = np.mean((cand_emb - prev_emb) ** 2)
        if emb_dist < best_dist:
            best_dist = emb_dist
            best_track_idx = n
    
    if best_dist < thr:
        return candidates[best_track_idx]
    return prev

# %%
for img in data['05-Shape_video00009'][0]:
    image = Image.open(img).convert('RGB')
    sized = image.resize((m.width, m.height))
    boxes = do_detect(m, sized, 0.5, 0.4, use_cuda)
    for box in boxes:
        bbox = [float(x) for x in box[:4]]
        plot_single(image, bbox)
    plt.show()
    plt.close()

# %%
def best_iou(candidates, gt, width=None, height=None):
    best_iou = 0
    best_index = 0
    _iou = 0
    for i, candidate in enumerate(candidates):
#         print("SYKA BLYAT", candidate)
        if len(candidate) > 4:
            candidate = candidate[0:4]
        if width is not None:
            x1 = (candidate[0] - candidate[2] / 2.0) * width
            y1 = (candidate[1] - candidate[3] / 2.0) * height
            x2 = (candidate[0] + candidate[2] / 2.0) * width
            y2 = (candidate[1] + candidate[3] / 2.0) * height
            candidate = np.array([x1, y1, x2, y2])
        _iou = iou(candidate, gt)
        print(candidate, gt, _iou, sep="\n")
        if _iou > best_iou:
            best_iou = _iou
            best_index = i
    return candidates[best_index] if _iou > 0 else None

# %%
def file2tensor(file):
    with open(file, 'r') as f:
        lines = torch.tensor([[float(y) for y in x.split()] for x in f.readlines()])
        return lines

# %%
def read_gt(file, idx=None):
    tensor = file2tensor(file)
    if idx is not None:
        return tensor[idx]
    else:
        return tensor

# %%
def tensor_to_bb(gt, gt_idx):
    gt_bb = gt[gt[:, 0] <= gt_idx + 1][-1]
    index, gt_bb = gt_bb[0].tolist(), gt_bb[1:].tolist()
    return index, gt_bb

# %%
def force_square(m):
    return [min(m[::2]), min(m[1::2]), max(m[::2]), max(m[1::2])]

# %%
hero = None
for img in data['08-Clutter_video00001'][0]:
    image = Image.open(img).convert('RGB')
    sized = image.resize((m.width, m.height))
    boxes = do_detect(m, sized, 0.5, 0.4, use_cuda)
    for box in boxes:
        plot_single(image, box)
    if len(boxes) == 0:
        plot_single(image, hero)
        plt.show()
        plt.close()
        continue
    if hero is None:
        gt = read_gt(data['08-Clutter_video00001'][1])
        true_box = tensor_to_bb(gt, 0)[1]
        hero = best_iou(boxes, force_square(true_box), image.width, image.height)
    hero = choose_best_by_emb(hero, boxes)

    plt.show()
    plt.close()
# Out:
# [ 815.3972     46.906944 1283.304     548.4516  ]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [ 35.10418 473.72424 430.49768 704.84656]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [ 93.972206 108.4251   558.8389   517.3307  ]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [754.8131  579.96204 892.1622  726.27026]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [188.68124 589.8085  335.08752 732.7391 ]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [403.948   447.23972 670.73114 583.4409 ]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [600.3817  468.77496 876.9726  694.6746 ]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# [ 956.15894  582.6325  1079.9722   710.18823]
# [462.5400085449219, 632.1500244140625, 491.42999267578125, 670.9500122070312]
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-027be1048335> in <module>
#      15         true_box = tensor_to_bb(gt, 0)[1]
#      16         hero = best_iou(boxes, force_square(true_box), image.width, image.height)
# ---> 17     hero = choose_best_by_emb(hero, boxes)
#      18
#      19     plt.show()
#
# <ipython-input-28-acb78a0eb40a> in choose_best_by_emb(prev, candidates, thr)
#       3     best_track_idx = 0
#       4
# ----> 5     prev_emb = np.array(prev[8:1032])
#       6
#       7     for n, candidate in enumerate(candidates):
#
# TypeError: 'NoneType' object is not subscriptable
